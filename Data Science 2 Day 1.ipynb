# %%
Data Science 2 Day 1
# Out:
#   File "<ipython-input-1-2054ee46966c>", line 1
#     Data Science 2 Day 1
#          ^
# SyntaxError: invalid syntax

# %%
#load pandas into python

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#making a simple dataframe
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4,5,6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df['A']
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
#New column

df['C'] = df['A']*df['B']
df
# Out:
#    A  B   C
# 0  1  4   4
# 1  2  5  10
# 2  3  6  18

# %%
#Reading data into pandas
#we have read csv method but the users table is in tbl format. Hence, using | seperator 
users = pd.read_csv('user.tbl', sep = '|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
type(users)
# Out:
# pandas.core.frame.DataFrame

# %%
#what are the top 5 rows of my df?

users.head(7)
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344

# %%
users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
#How many rows there are

users.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %%
#What are the columns?

users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
users['age']
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
# grabbing a single column

users.age
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
users[['age']]
# Out:
#      age
# 0     24
# 1     53
# 2     23
# 3     24
# 4     33
# ..   ...
# 938   26
# 939   32
# 940   20
# 941   48
# 942   22
#
# [943 rows x 1 columns]

# %%
#what are the data types?
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# how many rows & columns? Shape is a method

users.shape
# Out:
# (943, 5)

# %%
users.values
# Out:
# array([[1, 24, 'M', 'technician', '85711'],
#        [2, 53, 'F', 'other', '94043'],
#        [3, 23, 'M', 'writer', '32067'],
#        ...,
#        [941, 20, 'M', 'student', '97229'],
#        [942, 48, 'F', 'librarian', '78209'],
#        [943, 22, 'M', 'student', '77841']], dtype=object)

# %%
#finding nulls

users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
users['gender'].shape
# Out:
# (943,)

# %%
users[['gender']].shape
# Out:
# (943, 1)

# %%
type(users['gender'])
# Out:
# pandas.core.series.Series

# %%
type(users[['gender']])
# Out:
# pandas.core.frame.DataFrame

# %%
#describe method

users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
#make describe work on all columns

users.describe(include = 'all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
users['age'].describe()
# Out:
# count    943.000000
# mean      34.051962
# std       12.192740
# min        7.000000
# 25%       25.000000
# 50%       31.000000
# 75%       43.000000
# max       73.000000
# Name: age, dtype: float64

# %%
users.gender.describe()
# Out:
# count     943
# unique      2
# top         M
# freq      670
# Name: gender, dtype: object

# %%
users.age.mean()
# Out:
# 34.05196182396607

# %%
#make a histogram of age

users.age.hist();

# %%
# counting a categorical variable

users.gender.value_counts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
users.gender.value_counts().plot(kind = 'bar');

# %%
users.age.value_counts()
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 7      1
# 66     1
# 10     1
# 11     1
# 73     1
# Name: age, Length: 61, dtype: int64

# %%
#using sort index method

users.age.value_counts().sort_index()
# Out:
# 7     1
# 10    1
# 11    1
# 13    5
# 14    3
#      ..
# 66    1
# 68    2
# 69    2
# 70    3
# 73    1
# Name: age, Length: 61, dtype: int64

# %%
users.age.value_counts().sort_index().plot(kind = 'bar', figsize = (10,10))
plt.xlabel('Age');
plt.ylabel('Number of users');
plt.title('Number of users per age');

# %%
drinks = pd.read_csv('drinks.csv')

# %%
#1) Print the first and last 5 rows of the data

drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#1) Print the first and last 5 rows of the data

drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
#2) Examine the index, datatypes and shape of the drinks data

drinks.index
drinks.dtypes
print(drinks)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
#2) Examine the index, datatypes and shape of the drinks data

drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
#2) Examine the index, datatypes and shape of the drinks data

drinks.shape
# Out:
# (193, 6)

# %%
#3) Print the first 5 rows of the beer_servings column

drinks.beer_servings.head()
# Out:
# 0      0
# 1     89
# 2     25
# 3    245
# 4    217
# Name: beer_servings, dtype: int64

# %%
#4) Calculate the average beer_servings for the entire data set

drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
#5) Count the number of occurrences of each 'continent' value

drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
users[users['age'] < 20].head()
# Out:
#     user_id  age gender occupation zip_code
# 29       30    7      M    student    55436
# 35       36   19      F    student    93117
# 51       52   18      F    student    55105
# 56       57   16      M       none    84010
# 66       67   17      M    student    60402

# %%
users.occupation = 'student'

# %%
drinks.continent.value_counts().plot(kind='bar');

# %% [markdown]
# # Filtering and Sorting

# %%
#filtering to find users younger than 20
users[users['age'] < 20]
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 35        36   19      F    student    93117
# 51        52   18      F    student    55105
# 56        57   16      M    student    84010
# 66        67   17      M    student    60402
# ..       ...  ...    ...        ...      ...
# 871      872   19      F    student    74078
# 879      880   13      M    student    83702
# 886      887   14      F    student    27249
# 903      904   17      F    student    61073
# 924      925   18      F    student    49036
#
# [77 rows x 5 columns]

# %%
mask = users['age'] < 20
users[mask]
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 35        36   19      F    student    93117
# 51        52   18      F    student    55105
# 56        57   16      M    student    84010
# 66        67   17      M    student    60402
# ..       ...  ...    ...        ...      ...
# 871      872   19      F    student    74078
# 879      880   13      M    student    83702
# 886      887   14      F    student    27249
# 903      904   17      F    student    61073
# 924      925   18      F    student    49036
#
# [77 rows x 5 columns]

# %%
mask2 = users['occupation'] == 'student'
users[mask2]
# Out:
#      user_id  age gender occupation zip_code
# 0          1   24      M    student    85711
# 1          2   53      F    student    94043
# 2          3   23      M    student    32067
# 3          4   24      M    student    43537
# 4          5   33      F    student    15213
# ..       ...  ...    ...        ...      ...
# 938      939   26      F    student    33319
# 939      940   32      M    student    02215
# 940      941   20      M    student    97229
# 941      942   48      F    student    78209
# 942      943   22      M    student    77841
#
# [943 rows x 5 columns]

# %%
# find unique values of age

users.age.unique()
# Out:
# array([24, 53, 23, 33, 42, 57, 36, 29, 39, 28, 47, 45, 49, 21, 30, 35, 40,
#        26, 25, 32, 41,  7, 38, 20, 19, 27, 18, 22, 37, 16, 50, 31, 51, 17,
#        48, 34, 43, 60, 55, 15, 61, 44, 54, 59, 46, 13, 52, 56, 14, 66, 62,
#        11, 65, 68, 63, 64, 10, 73, 58, 69, 70], dtype=int64)

# %%
users = pd.read_csv('user.tbl', sep = '|')

# %%
mask1 = users['occupation'] == 'student'
users[mask1]
# Out:
#      user_id  age gender occupation zip_code
# 8          9   29      M    student    01002
# 29        30    7      M    student    55436
# 31        32   28      F    student    78741
# 32        33   23      M    student    27510
# 35        36   19      F    student    93117
# ..       ...  ...    ...        ...      ...
# 927      928   21      M    student    55408
# 932      933   28      M    student    48105
# 938      939   26      F    student    33319
# 940      941   20      M    student    97229
# 942      943   22      M    student    77841
#
# [196 rows x 5 columns]

# %%
mask3 = (drinks.beer_servings > 25) & (drinks.continent == 'EU' )
drinks[mask3]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 9               Austria            279               75            191
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# ...

# %%
mask4 = ((drinks.beer_servings > 25) & (drinks.continent== 'EU' ))| (drinks.wine_servings >200)
drinks[mask4]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 6             Argentina            193               25            221
# 8             Australia            261               72            212
# 9               Austria            279               75            191
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
#isin condition

users[users.occupation.isin(['lawyer', 'doctor'])]
# Out:
#      user_id  age gender occupation zip_code
# 9         10   53      M     lawyer    90703
# 124      125   30      M     lawyer    22202
# 125      126   28      F     lawyer    20015
# 137      138   46      M     doctor    53211
# 160      161   50      M     lawyer    55104
# 204      205   47      M     lawyer    06371
# 250      251   28      M     doctor    85032
# 298      299   29      M     doctor    63108
# 338      339   35      M     lawyer    37901
# 364      365   29      M     lawyer    20009
# 418      419   37      M     lawyer    43215
# 426      427   51      M     doctor    85258
# 443      444   51      F     lawyer    53202
# 588      589   21      M     lawyer    90034
# 679      680   33      M     lawyer    90405
# 840      841   45      M     doctor    47401
# 844      845   64      M     doctor    97405
# 845      846   27      M     lawyer    47130
# 934      935   42      M     doctor    66221

# %%
# sort values method

users.sort_values('age', ascending = False).head()
# Out:
#      user_id  age gender     occupation zip_code
# 480      481   73      M        retired    37771
# 802      803   70      M  administrator    78212
# 766      767   70      M       engineer    00000
# 859      860   70      F        retired    48322
# 584      585   69      M      librarian    98501

# %%
users.sort_values(['occupation','age'], ascending = [True, False])
# Out:
#      user_id  age gender     occupation zip_code
# 802      803   70      M  administrator    78212
# 265      266   62      F  administrator    78756
# 130      131   59      F  administrator    15237
# 818      819   59      M  administrator    40205
# 6          7   57      M  administrator    91344
# ..       ...  ...    ...            ...      ...
# 800      801   22      M         writer    92154
# 49        50   21      M         writer    52245
# 444      445   21      M         writer    92653
# 506      507   18      F         writer    28450
# 619      620   18      F         writer    81648
#
# [943 rows x 5 columns]

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
#freezinf a sorted dateframe
users.sort_values(['occupation','age'], ascending = [True, False], inplace=True)
users.head()
# Out:
#      user_id  age gender     occupation zip_code
# 802      803   70      M  administrator    78212
# 265      266   62      F  administrator    78756
# 130      131   59      F  administrator    15237
# 818      819   59      M  administrator    40205
# 6          7   57      M  administrator    91344

# %%
#1) Filter the DataFrame to only include European countries

EU = drinks['continent'] == 'EU'
drinks[EU]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
#2) Filter the DataFrame to only include European countries with wine_servings > 300

EU1 = (drinks['continent'] == 'EU') & (wine_servings > 300)
drinks[EU1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-6616ed85f09a> in <module>
#       1 #2) Filter the DataFrame to only include European countries with wine_servings > 300
#       2
# ----> 3 EU1 = (drinks['continent'] == 'EU') & (wine_servings > 300)
#       4 drinks[EU1]
#
# NameError: name 'wine_servings' is not defined

# %%
drinks = pd.read_csv('drinks.csv')

# %%
EU1 = (drinks['continent'] == 'EU') & (drinks.wine_servings > 300)
drinks[EU1]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %%
#3) Calculate the average beer_servings for all of Europe

##drinks.beer_servings.mean() 

mask12 = (drinks.continent == 'EU')
drinks[mask12].beer_servings.mean()
# Out:
# 193.77777777777777

# %%
#4) Determine which 10 countries have the highest total_litres_of_pure_alcohol

drinks.sort_values('total_litres_of_pure_alcohol', ascending = False).head(10)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# 81              Ireland            313              118            165
# 155            Slovakia            196              293            116
# 99           Luxembourg            236              133            271
#
#      total_litres_of_pure_alcohol continent
# 15                           14.4        EU
# 98                           12.9        EU
# 3                            12.4        EU
# ...
